# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# **Task 1**

# %%
filename = 'oct-08-singapore.txt'

month_dict = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
}

parts = filename.split('-')
month_abbr = parts[0]
day = parts[1]
city_with_extension = parts[2]

if month_abbr in month_dict:
    new_month = month_dict[month_abbr]
    new_filename = f'{new_month}-{day}-{city_with_extension}'
    filename = new_filename

print(filename)
# Out:
# 10-08-singapore.txt

# %% [markdown]
# **Task 2**

# %%
def rename_my_file(old_file_name):
    """
    Renames a file from month-day-city.txt format to mm-dd-city.txt format.

    Args:
        old_file_name: The original filename.

    Returns:
        The new filename.
    """

    month_dict = {
        'jan': '01', 'feb': '02', 'mar': '03',
        'apr': '04', 'may': '05', 'jun': '06',
        'jul': '07', 'aug': '08', 'sep': '09',
        'oct': '10', 'nov': '11', 'dec': '12'
    }

    parts = old_file_name.split('-')
    month_abbr = parts[0]
    day_city = parts[1] #capture day_city together.
    if month_abbr in month_dict:
        new_month = month_dict[month_abbr]
        new_file_name = f'{new_month}-{day_city}'
        return new_file_name
    else:
        return old_file_name

# %% [markdown]
# **Task 3**

# %%
file_list = [
    'oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
    'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
    'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
    'jan-01_tokyo.txt'
]

for old_file in file_list:
    new_file = rename_my_file(old_file)
    print(f"{old_file} ----> {new_file}")
# Out:
# oct-08_singapore.txt ----> 10-08_singapore.txt
# jul-10_cairo.txt ----> 07-10_cairo.txt
# may-15_dhaka.txt ----> 05-15_dhaka.txt
# may-13_cairo.txt ----> 05-13_cairo.txt
# oct-21_cairo.txt ----> 10-21_cairo.txt
# jan-10_singapore.txt ----> 01-10_singapore.txt
# jun-20_tokyo.txt ----> 06-20_tokyo.txt
# aug-06_jakarta.txt ----> 08-06_jakarta.txt
# dec-21_karachi.txt ----> 12-21_karachi.txt
# jan-01_tokyo.txt ----> 01-01_tokyo.txt

# %% [markdown]
# **Task 4**

# %%
import os
import glob
folder_path = r"C:\Users\Admin\Downloads\sp2273zip\os-collaboration-exercise-data"

try:
    os.chdir(folder_path)
    print(f"Successfully changed directory to: {os.getcwd()}")

    txt_files = glob.glob("*.txt") #Get all txt files

    for old_file in txt_files:
        new_file = rename_my_file(old_file)
        if new_file != old_file: #only rename if names are different.
            os.rename(old_file, new_file)
            print(f"Renamed: {old_file} ----> {new_file}")

except FileNotFoundError:
    print(f"Error: Folder '{folder_path}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Successfully changed directory to: C:\Users\Admin\Downloads\sp2273zip\os-collaboration-exercise-data
# Renamed: apr-01_melbourne.txt ----> 04-01_melbourne.txt
# Renamed: apr-01_shanghai.txt ----> 04-01_shanghai.txt
# Renamed: apr-01_singapore.txt ----> 04-01_singapore.txt
# Renamed: apr-02_cairo.txt ----> 04-02_cairo.txt
# Renamed: apr-02_jakarta.txt ----> 04-02_jakarta.txt
# Renamed: apr-02_karachi.txt ----> 04-02_karachi.txt
# Renamed: apr-02_shanghai.txt ----> 04-02_shanghai.txt
# Renamed: apr-03_manila.txt ----> 04-03_manila.txt
# Renamed: apr-03_osaka.txt ----> 04-03_osaka.txt
# Renamed: apr-03_singapore.txt ----> 04-03_singapore.txt
# Renamed: apr-03_tokyo.txt ----> 04-03_tokyo.txt
# Renamed: apr-04_manila.txt ----> 04-04_manila.txt
# Renamed: apr-04_melbourne.txt ----> 04-04_melbourne.txt
# Renamed: apr-04_shanghai.txt ----> 04-04_shanghai.txt
# Renamed: apr-04_singapore.txt ----> 04-04_singapore.txt
# Renamed: apr-05_karachi.txt ----> 04-05_karachi.txt
# ...

# %% [markdown]
# **Task 5**

# %%
import os

# Cities for which to create folders
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
          'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for city in cities:
    try:
        os.makedirs(city)  # Create the folder if it doesn't exist
        print(f"Created folder: {city}")
    except FileExistsError:
        print(f"Folder '{city}' already exists.")
    except Exception as e:
        print(f"An error occurred while creating '{city}': {e}")
# Out:
# Folder 'Cairo' already exists.
# Folder 'Dhaka' already exists.
# Folder 'Jakarta' already exists.
# Folder 'Karachi' already exists.
# Folder 'Manila' already exists.
# Folder 'Melbourne' already exists.
# Folder 'Osaka' already exists.
# Folder 'Shanghai' already exists.
# Folder 'Singapore' already exists.
# Folder 'Tokyo' already exists.

# %% [markdown]
# **Task 6**

# %%
import glob
import shutil

# Task 7: Copy Cairo files to the Cairo folder

cairo_files = glob.glob("*Cairo*")  # Find all Cairo files

for file in cairo_files:
    try:
        shutil.copy(file, "Cairo")  # Copy the file to the Cairo folder
        print(f"Copied '{file}' to 'Cairo'")
    except FileNotFoundError:
        print(f"Error: File '{file}' not found.")
    except Exception as e:
        print(f"An error occurred while copying '{file}': {e}")
# Out:
# An error occurred while copying 'Cairo': [Errno 13] Permission denied: 'Cairo'

# %% [markdown]
# **Task 7**

# %%
import glob
import shutil
import os

# Task 7: Move all files to their respective city folders

cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
          'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for city in cities:
    # Use glob to find files related to the current city
    # The '*' before and after the city name ensures it captures files 
    # with any prefix or suffix, as long as they contain the city name
    city_files = glob.glob(f"*{city}*")  
    
    for file in city_files:
        try:
            # Construct the destination path by joining the city name 
            # (which is also the folder name) with the filename
            destination_path = os.path.join(city, file)  
            
            shutil.move(file, destination_path)  # Move the file
            print(f"Moved '{file}' to '{destination_path}'")
        except FileNotFoundError:
            print(f"Error: File '{file}' not found.")
        except Exception as e:
            print(f"An error occurred while moving '{file}': {e}")
# Out:
# An error occurred while moving 'Cairo': Cannot move a directory 'Cairo' into itself 'Cairo\Cairo'.
# An error occurred while moving 'Dhaka': Cannot move a directory 'Dhaka' into itself 'Dhaka\Dhaka'.
# An error occurred while moving 'Jakarta': Cannot move a directory 'Jakarta' into itself 'Jakarta\Jakarta'.
# An error occurred while moving 'Karachi': Cannot move a directory 'Karachi' into itself 'Karachi\Karachi'.
# An error occurred while moving 'Manila': Cannot move a directory 'Manila' into itself 'Manila\Manila'.
# An error occurred while moving 'Melbourne': Cannot move a directory 'Melbourne' into itself 'Melbourne\Melbourne'.
# An error occurred while moving 'Osaka': Cannot move a directory 'Osaka' into itself 'Osaka\Osaka'.
# An error occurred while moving 'Shanghai': Cannot move a directory 'Shanghai' into itself 'Shanghai\Shanghai'.
# An error occurred while moving 'Singapore': Cannot move a directory 'Singapore' into itself 'Singapore\Singapore'.
# ...
